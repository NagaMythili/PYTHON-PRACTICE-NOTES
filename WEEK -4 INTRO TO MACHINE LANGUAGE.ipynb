# %% [markdown]
# # MACHINE LEARNING
#   ---> This ML is a domain
#   ---> Non-Traditional Programming Language
#   ---> It accept Inputs as well as Output from User &Built Model.
#   ---> This ML is Sub-Set of AI.

# %% [markdown]
#  Traditional Programming Languages
# ------------------------------------------------------
# 1.c
# 2.cpp
# 3.java
# 4.python....
#
# Non-Traditional Programming Languages
# -------------------------------------------------------------
# ---like websites
# 1.AI
# 2.ML
# 3.Deep Learning

# %% [markdown]
# ![tradi.jpg](attachment:tradi.jpg)

# %% [markdown]
# ![non%20tradi.jpg](attachment:non%20tradi.jpg)

# %% [markdown]
# # PROBLEM FORMULATION
# -----> It is a process of identifying the problem and arranged in well organized manner to obtain the accurate Results.
# we need to follow 4 steps here:
#
#     (i)   Problem Definition
#     (ii)  Problem Analysis
#     (iii) Knowledge Representation (in data a small part as knowledge to do opearions using that small data)
#     (iv)  Problem - Solving
